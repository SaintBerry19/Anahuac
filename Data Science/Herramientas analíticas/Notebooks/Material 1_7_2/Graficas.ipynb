# %%
using Plots

# %%
x = 1:10
y = rand(10)

p = plot(x,y, dpi=300, size=(800,600));
savefig(p,"plot.png")

# %%
savefig(p,"plot.png")

# %%
p = plot(x,y)
z = rand(10)
plot!(p,x,z)
p

# %%
y = rand(10,2)
plot(x,y, title="Título de gráfica", label=["serie 1" "serie 2"], lw = 5)

# %%
p = xlabel!("Eje X")

# %%
plot(x,y, title="Título de gráfica",seriestype=:scatter, label=["serie 1" "serie 2"])

# %%
display(p)

# %%
y = rand(10,8)
plot(x,y,layout=(2,2))

# %%
y = rand(10,1)
p1 = plot(x,y)
p2 = scatter(x,y)
p3 = bar(x,y)
p4 = histogram(x,y, fillcolor="red")
plot(p1,p2,p3,p4,layout=(2,2),legend=false)
